# %%
import pandas as pd

# %%
result=pd.read_csv('result.csv')
result.head(10)
# Out:
#    Unnamed: 0                           title  \
# 0           0                   Affenpinscher
# 1           0                    Afghan Hound
# 2           0                Airedale Terrier
# 3           0                Alaskan Klee Kai
# 4           0                Alaskan Malamute
# 5           0                American Bulldog
# 6           0             American Eskimo Dog
# 7           0               American Foxhound
# 8           0  American Staffordshire Terrier
# 9           0          Anatolian Shepherd Dog
#
#                                          HEIGHT  \
# 0                                 9-11.5 inches
# 1                                  25-27 inches
# 2                                     23 inches
# 3                                12 - 17 inches
# 4                              25 inches (male)
# 5  22-25 inches (males); 20-23 inches (females)
# 6                             9-12 inches (toy)
# 7                           22-25 inches (male)
# ...

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'title', 'HEIGHT', 'WEIGHT', 'LIFE EXPECTANCY',
#        'AFFECTIONATE WITH FAMILY', 'GOOD WITH YOUNG CHILDREN',
#        'GOOD WITH OTHER DOGS', 'SHEDDING LEVEL', 'COAT GROOMING FREQUENCY',
#        'DROOLING LEVEL', 'COAT TYPE', 'COAT LENGTH', 'OPENNESS TO STRANGERS',
#        'PLAYFULNESS LEVEL', 'WATCHDOG/PROTECTIVE NATURE', 'ADAPTABILITY LEVEL',
#        'TRAINABILITY LEVEL', 'ENERGY LEVEL', 'BARKING LEVEL',
#        'MENTAL STIMULATION NEEDS', 'Unnamed: 21'],
#       dtype='object')

# %%
data=result.iloc[:,1:-1].rename(columns={"title": "BREED"})
data['HEIGHT']=data['HEIGHT'].apply(lambda x:x.split(' ')[0])
data['WEIGHT']=data['WEIGHT'].apply(lambda x:x.split(' ')[0])
data['LIFE EXPECTANCY']=data['LIFE EXPECTANCY'].apply(lambda x:x.split(' ')[0])

data
# Out:
#                            BREED  HEIGHT WEIGHT LIFE EXPECTANCY  \
# 0                  Affenpinscher  9-11.5   7-10           12-15
# 1                   Afghan Hound   25-27  50-60           12-18
# 2               Airedale Terrier      23  50-70           11-14
# 3               Alaskan Klee Kai      12      6           13-16
# 4               Alaskan Malamute      25     85           10-14
# ..                           ...     ...    ...             ...
# 194                      Whippet   19-22  25-40           12-15
# 195  Wirehaired Pointing Griffon   22-24  50-70           12-15
# 196            Wirehaired Vizsla   23-25  55-65           12-14
# 197               Xoloitzcuintli   10-14  10-15           13-18
# 198               Yakutian Laika   21-23  40-55           10-12
#
#      AFFECTIONATE WITH FAMILY  GOOD WITH YOUNG CHILDREN  GOOD WITH OTHER DOGS  \
# 0                         3.0                       3.0                   3.0
# ...
